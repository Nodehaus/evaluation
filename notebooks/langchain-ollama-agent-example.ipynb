# %%
from langchain.agents import initialize_agent, AgentType
from langchain_community.llms import Ollama
from langchain.tools import Tool

# %%
# example models: qwen:0.5b, qwen2.5, llama3.2:3b

# %%
# connect to your ollama endpoint
llm = Ollama(
    model="qwen2.5",
    base_url="https://moaning-reeva-nodehausio-80186abe.koyeb.app" 
)

# %%
# simple tool for the agent to use
def multiply_numbers(numbers: str) -> str:
    """Multiply a list of numbers given as a comma-separated string."""
    try:
        nums = [float(n.strip()) for n in numbers.split(",")]
        result = 1
        for n in nums:
            result *= n
        return str(result)
    except Exception as e:
        return f"Error: {e}"

multiply_tool = Tool(
    name="MultiplyNumbers",
    func=multiply_numbers,
    description="Multiply a list of numbers. Input should be comma-separated numbers."
)

# %%
# initialize an agent with the tool and llm
agent = initialize_agent(
    tools=[multiply_tool],
    llm=llm,
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,
    verbose=True,
    handle_parsing_errors=True
)

# %%
# run prompt
response = agent.run("What is 12 * 7 * 3?")
print("Agent Response:", response)
